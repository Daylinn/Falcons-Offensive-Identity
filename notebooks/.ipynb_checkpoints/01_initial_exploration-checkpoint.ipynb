# %%
import sys
import os

# Fix Python path for imports
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

import pandas as pd
from src.data_loader import load_pbp_season, filter_falcons_offense
from src.preprocess import DrivePreprocessor

# %%
import pandas as pd
from src.data_loader import load_pbp_season, filter_falcons_offense

df16 = load_pbp_season("../data/raw/pbp_2016.csv.gz")
df23 = load_pbp_season("../data/raw/pbp_2023.csv.gz")

falcons16 = filter_falcons_offense(df16)
falcons23 = filter_falcons_offense(df23)

# %%
processor = DrivePreprocessor()
drives16 = processor.transform(falcons16)
drives23 = processor.transform(falcons23)
drives16.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/falcons_offensive_identity/.conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/falcons_offensive_identity/.conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/falcons_offensive_identity/.conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'personnel_offense'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 processor = DrivePreprocessor()
# ----> 2 drives16 = processor.transform(falcons16)
#       3 drives23 = processor.transform(falcons23)
#       4 drives16.head()
#
# File ~/falcons_offensive_identity/src/preprocess.py:71, in DrivePreprocessor.transform(self, df)
#      66 """
#      67 Main pipeline for converting PBP data into drive-level identity features.
#      68 """
#      69 df = df.copy()
# ---> 71 df = self._extract_personnel(df)
#      72 df = self._compute_play_metrics(df)
#      74 drives = self._aggregate_to_drives(df)
#
# File ~/falcons_offensive_identity/src/preprocess.py:28, in DrivePreprocessor._extract_personnel(self, df)
#      21     parts = {x.split()[1]: int(x.split()[0]) for x in p.split(", ")}
#      22     return pd.Series([
#      23         parts.get("RB", 0),
#      24         parts.get("TE", 0),
#      25         parts.get("WR", 0),
#      26     ])
# ---> 28 df[["RB_count", "TE_count", "WR_count"]] = df["personnel_offense"].apply(parse_personnel)
#      29 return df
#
# File ~/falcons_offensive_identity/.conda/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/falcons_offensive_identity/.conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'personnel_offense'
